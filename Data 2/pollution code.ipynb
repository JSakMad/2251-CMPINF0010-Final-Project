# %%
import pandas as pd
import matplotlib.pyplot as plt

# Find needed data
df = pd.read_csv('air quality.csv') 
non_good_data = df[data['description'] != 'Good']
site_counts = non_good_data['site'].value_counts().sort_values(ascending=True)

# Create graph
site_counts.plot(kind='bar', color='grey')
plt.title('Count of Non-Good Descriptions by Site (Least to Greatest)')
plt.xlabel('Source Site')
plt.ylabel('Count')
plt.xticks(rotation=50, ha='right')
plt.show()
